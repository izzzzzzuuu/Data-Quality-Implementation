# %% [markdown]
# # Accessing data
# ## Access raw data from Azure container
# - Create connection to Azure Blob Storage
# - Convert the CSV file into parquet file format
# - Upload the parquet file into Bronze layer/folder
#
# ## Access uploaded parquet file from the Bronze layer
# - Download the specific blob
# - Load data into dataframes using Pandas

# %% [markdown]
# ### Installation of Azure Storage Blob

# %%
# pip install azure-storage-blob

# %% [markdown]
# ### Create a connection to the Azure Blob Storage

# %%
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient

# %%
# Connection string  and Container Name containing Azure Blob Storage account information
connection_string = "DefaultEndpointsProtocol=https;AccountName=**your_account_name**;AccountKey=**your_account_key**==;EndpointSuffix=core.windows.net"
container_name = "training"  ## your container name in Azure

# %%
# Create a BlobServiceClient object to interact with Azure Blob Storage
blob_service_client = BlobServiceClient.from_connection_string(connection_string)

# %%
# Connect to Azure Blob Storage and retrieve a ContainerClient for a specific container
container_client = blob_service_client.get_container_client(container_name)

# %%
# List blobs in the container
blob_list = container_client.list_blobs()
for blob in blob_list:
    print(blob.name)
# Out:
# 01-Raw
# 01-Raw/dqdatademo.csv
# 02-Bronze
# 02-Bronze/dqdatademo.parquet
# 03-Silver
# 04-Gold

# %% [markdown]
# ### Converting the .csv to .parquet

# %%
 blob_name = "01-Raw/dqdatademo.csv"  # Specify the name of the CSV file

# %%
 blob_client = container_client.get_blob_client(blob_name)

# %%
# Download CSV data into memory
csv_data = blob_client.download_blob().readall().decode("utf-8")

# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from io import StringIO

# %%
# Convert CSV data to pandas DataFrame
df = pd.read_csv(StringIO(csv_data))

# %%
# Convert DataFrame to Parquet format
parquet_file_path = "dqdatademo.parquet"
table = pa.Table.from_pandas(df)
pq.write_table(table, parquet_file_path)

# %% [markdown]
# ### Upload the .parquet into Bronze file

# %%
# Upload the Parquet file back to Azure Blob Storage
parquet_blob_client = container_client.get_blob_client("02-Bronze/dqdatademo.parquet")
with open(parquet_file_path, "rb") as data:
    parquet_blob_client.upload_blob(data)

# %% [markdown]
# ## Create connection to Azure to access the uploaded parquet file in Bronze folder

# %% [markdown]
# ## Load the parquet file

# %%
import io
# Download a specific blob (e.g., 'sample_data.parquet') as a stream and load it into a pandas DataFrame
blob_name = '02-Bronze/dqdatademo.parquet'  # Replace with your blob name
blob_client = container_client.get_blob_client(blob_name)

# Download the blob content
blob_data = blob_client.download_blob().readall()

# Load the data into a pandas DataFrame using pyarrow
data = pq.read_table(io.BytesIO(blob_data)).to_pandas()

# Display the DataFrame
print(data.head())
# Out:
#         id              name                         email    country  age
# 0   502797    James Williams            dreyes@example.com    Germany   24
# 1  3955827      Eileen Perez       vancesierra@example.com        USA   46
# 2  2985040  Brittney Daniels        brendaowen@example.net    Germany   47
# 3  1678851      Linda Wilson  contrerasrebecca@example.net  Australia   19
# 4  4307350       Jacob Tapia            gallen@example.com    Germany    8

# %%
# Convert Arrow Table to pandas DataFrame
df = table.to_pandas()

# %%
# Display the original DataFrame
print("Original DataFrame:")
df.sample(5)
# Out:
# Original DataFrame:
#               id               name                   email    country  age
# 2722431  2112089     Sarah Franklin  sethwilson@example.net  Singapore   41
# 499280   1525501      Jessica Morse   qpeterson@example.org  Australia   25
# 4199703  3125303  Stephen Maldonado    travis76@example.com      China   79
# 2496385   376548      Amber Schmidt    xjohnson@example.org   Malaysia   20
# 3842164   749767    Laurie Anderson      jbaker@example.net  Singapore   92

# %% [markdown]
# ## Split name column to further breakdown and prepare the dataset
# - divide into 7 column; id, Prefix, name, Title, age, email, country
# - Drop 'prefix' column as the 'Mr or Ms' title unable to be referenced to other columns, however, title "Dr." is deemed significant
# - The pattern [IVX] is a character set or character class in regular expressions. It matches a single character that is either "I", "V", or "X". Here's what each character in the set

# %%
import re
import pandas as pd


def separate_name(name):
    # Define regex pattern
    pattern = r'(?P<prefix>Mr\.|Ms\.|Mrs\.|Miss|Dr\.)?\s*(?P<name>.+?)(?:\s+(?P<title>[IVX]+|PhD|MD|DVM|DDS|Jr.))?$'

    match = re.match(pattern, name)
    if match:
        title = match.group('prefix')
        abbrev = match.group('title')
        name = match.group('name').strip()
        
        return title, name, abbrev
    else:
        return None, None, None
        
# Assign new variable to splitted name column parquet dataset
df_splitted_name = pd.DataFrame(df) # <-- dqdatademo dataset

# Apply the function to each row
df_splitted_name[['prefix', 'name', 'title']] = df_splitted_name['name'].apply(separate_name).apply(pd.Series)

# %%
df_splitted_name.sample(10)
# Out:
#               id               name                        email    country  \
# 216476   1356659     Matthew Huerta         joshua75@example.com   Malaysia
# 2137940    20466    Frederick Davis     jasminknight@example.com     Canada
# 1918822  2254486       Aaron Harris          abailey@example.org  Australia
# 4031388   297752    Courtney Taylor           sburke@example.org     France
# 3499828  2351961      Andrea Curtis       jerrymoore@example.net      India
# 4746294  3848625   Matthew Espinoza          cindy82@example.org      China
# 4908700  2496901       Eric Huffman        rowekarla@example.net   Malaysia
# 945081   3025297  Patricia Williams  floreschristina@example.com  Australia
# 4844664  3780060      Lauren Wright       courtney08@example.net         UK
# 1152944  3491809     Angela Johnson       efernandez@example.net    Germany
#
#          age prefix title
# 216476    81   None  None
# 2137940   13   None  None
# 1918822   27   None  None
# 4031388    8   None  None
# 3499828   81   None  None
# 4746294   50   None  None
# 4908700   22   None  None
# 945081    86   None  None
# 4844664   64   None  None
# 1152944   35   None  None

# %%
df_splitted_name.shape
# Out:
# (5000000, 7)

# %% [markdown]
# ### Rearrange columns for readability

# %%
# Specify the desired column order
desired_columns = ['id','prefix', 'name', 'title', 'email', 'country', 'age']


# Reassign the DataFrame with the columns in the desired order
new_df = df_splitted_name[desired_columns]

# %%
new_df.sample(10)
# Out:
#               id prefix               name title  \
# 2607510  1660713   None        Tracy Singh  None
# 3925422  4234425   None    Denise Mitchell  None
# 250111   1152739   None     Robert Griffin  None
# 668072   3836462   None      Jeremy Thomas  None
# 3460207   136622   None   Justin Hernandez  None
# 1067325  2600090   None       Jeffrey Love  None
# 3358981  3527423   None    Gwendolyn Smith  None
# 639103   3065682   None          Glen Cook  None
# 2197494  1243472   None      Tiffany Moore  None
# 404113   4284898   None  Miranda Armstrong  None
#
#                                 email      country  age
# 2607510           zgibson@example.com      Nigeria   44
# 3925422     hamiltonlinda@example.net        India   34
# 250111          desiree32@example.com  New Zealand   88
# 668072            kevin94@example.net     Malaysia   33
# 3460207      charleslucas@example.org       Canada   53
# 1067325    jonathancooper@example.org     Malaysia   37
# 3358981  christopherscott@example.com          USA   55
# 639103        christina39@example.org        India   96
# 2197494            imejia@example.com     Malaysia   84
# 404113            frank24@example.com     Malaysia   63

# %% [markdown]
# ### Before drop the prefix column, notice there are meaningful value; "Dr."

# %%
# Check if 'title' column contains 'Jr.'
search_string = 'Dr'
mask = new_df['prefix'].astype(str).str.contains(search_string, case=False)

# Filter DataFrame based on the mask
result = new_df[mask]

print(result)
# Out:
#               id prefix               name title                        email  \
# 168      3107966    Dr.     Rachel Webster  None       johnspears@example.com
# 270      3592176    Dr.    Reginald Waller  None  vanessasandoval@example.net
# 410       617151    Dr.        Shirley Lee  None            mtodd@example.com
# 544      4359633    Dr.      Ricardo Brown  None   francojennifer@example.com
# 654      1439545    Dr.   Yolanda Marshall    MD      stephanie98@example.net
# ...          ...    ...                ...   ...                          ...
# 4999560  3062506    Dr.       Cindy Harris  None       marshpedro@example.net
# 4999660  1647225    Dr.  Matthew Hernandez  None    michaelturner@example.com
# 4999692  3022538    Dr.    Kimberly Parker  None         lauren15@example.net
# 4999753  2884411    Dr.        Guy Vaughan   PhD           qcohen@example.com
# 4999920  2696234    Dr.        Bryan Woods    MD  stanleyschwartz@example.com
#
#              country  age
# 168         Malaysia   41
# 270           Canada   18
# 410      New Zealand   33
# 544      New Zealand   47
# 654              USA   97
# ...              ...  ...
# 4999560       France   32
# 4999660    Australia   28
# 4999692       Canada   81
# 4999753       Canada   30
# 4999920    Australia   45
#
# [29528 rows x 7 columns]

# %% [markdown]
# #### 29528 rows consist of Dr. prefixes.

# %% [markdown]
# # Start Data Profiling Process
# Measure Data Quality on Data that covering the following aspects:
# 1. Completeness - Replace meaningful value, "Dr." with mode value in title column
# 2. Consistency - Format consistent on email column - Alphabetical value
# 3. Consistency - Email domain column
# 4. Accuracy - Accuracy on the relation of name and email columns
# 5. Validity - Validity for title, age and email columns
# 6. Uniqueness - Deduplication on id and name columns

# %% [markdown]
# # 1. Completeness - prefix column with title column
#
# - Since "Dr." is meaningful data, we decided to replace it with mode value in the title column.
# - So, instead of "Dr. Christian Taylor", it will be "Christian Taylor < mode value>"
#
# Accepted data:
# - Prefix other than "Dr."
# - Title not null
#
# Rejected Data:
# - prefix column has "Dr."
# - title column is null

# %% [markdown]
# #### Dividing Accepted dataset and Rejected Dataset

# %%
# Check existence of "Dr." in 'prefix' column
dr_prefix_mask = new_df['prefix'].str.contains(r'^Dr\.', regex=True, na=False)

# Check for null values in 'title' column
null_title_mask = new_df['title'].isnull()

# Filter DataFrame based on conditions

#Rejected dataset
rejected_df = new_df[dr_prefix_mask & null_title_mask]

#Accepted dataset
accepted_df = new_df[~(dr_prefix_mask & null_title_mask)]

# %%
print("Accepted DataFrame:")
accepted_df.sample(20)
# Out:
# Accepted DataFrame:
#               id prefix               name title                        email  \
# 3892264  1244760   None         Mary Lopez  None      barrybailey@example.com
# 2252309  4368370   None   Nicholas Carroll  None        lwilliams@example.org
# 669652    589089   None      Charles Davis  None          lmiller@example.net
# 2480028    66780   None     Victor Jackson  None          dbecker@example.net
# 2265893  1387267   None      Michelle Park  None           lisa95@example.com
# 4778791    24953   None       Kayla Oneill  None   savannahmolina@example.net
# 135621    587611   None  Jennifer Stafford  None        browngary@example.org
# 1781527   190364   None       Michael Lang  None        ewilliams@example.org
# 1900105  2351783   None         Mary Duran  None    simpsondaniel@example.com
# 1184351  4458648   None       Cynthia Barr  None         samuel64@example.net
# 2462646   640122   None     Mark Hernandez  None          ggrimes@example.net
# 846542   4457488   None     Bethany Martin  None     dwaynethomas@example.net
# 3215599  2333798   None     Shawn Fletcher  None        patrick12@example.net
# 878685    376351    Mr.       David Walker   DVM           sgibbs@example.org
# 2954017  2467852   None       Joseph Adams  None         samuel07@example.net
# 629304   3875424   None    Jamie Maldonado  None          danny44@example.com
# 3855833   148056   None     Jason Anderson  None  jeanettevazquez@example.com
# 4202358  3921234   None      Charles Clark  None        michael99@example.net
# 1910371  3607958   None            Mark Wu  None             rray@example.com
# 4969522  3779667   None    Vincent Salazar  None        calebgray@example.org
#
#              country  age
# 3892264     Malaysia   11
# 2252309  New Zealand   57
# 669652     Singapore   18
# 2480028           UK   25
# 2265893       France   25
# 4778791     Malaysia   93
# 135621      Malaysia    1
# 1781527      Germany   70
# 1900105          USA   32
# 1184351  New Zealand   27
# 2462646    Singapore   73
# 846542       Nigeria   91
# 3215599     Malaysia   57
# 878685      Malaysia   62
# 2954017        India   83
# 629304      Malaysia   30
# 3855833      Germany   57
# 4202358           UK   96
# 1910371    Singapore   43
# 4969522  New Zealand   33

# %%
rejected_df.sample(10)
# Out:
#               id prefix              name title  \
# 2178113  3317671    Dr.   Melanie Freeman  None
# 4691943  1395530    Dr.  Stephanie Miller  None
# 1929851   963148    Dr.    Wendy Crawford  None
# 3041369  1444922    Dr.  Christine Miller  None
# 1554957  2713375    Dr.   Joseph Townsend  None
# 1485934  2131861    Dr.       Brent Keith  None
# 4473489  2332987    Dr.  Hannah Christian  None
# 1780247  1865576    Dr.      Sharon Jones  None
# 4141471   421744    Dr.   Amanda Ferguson  None
# 816121   2438442    Dr.       Shawn Smith  None
#
#                                   email      country  age
# 2178113             tracy07@example.net    Australia   98
# 4691943  stevenschristopher@example.org    Australia   95
# 1929851         shaunwright@example.org       France    9
# 3041369              ksmith@example.com  New Zealand   55
# 1554957           umatthews@example.org       Canada    4
# 1485934           jchambers@example.org           UK   68
# 4473489     walkeralejandra@example.org     Malaysia   80
# 1780247          jennifer47@example.org       Canada   42
# 4141471         nathaniel16@example.com        China   62
# 816121              craig94@example.com    Australia   15

# %%
rejected_df.shape
# Out:
# (22151, 7)

# %%
accepted_df.shape
# Out:
# (4977849, 7)

# %%
rejected_df_copy = rejected_df.copy()

# %% [markdown]
# ### Modify the rejected dataset
# - Replace the "Dr." inside the prefix column with **mode value** inside the title column

# %% [markdown]
# #### Mode value in title column

# %%
# Calculate mode value of 'title' column
mode_title = new_df['title'].mode()[0] if not new_df['title'].isnull().all() else None
print(mode_title)
# Out:
# MD

# %%
# Replace null values in 'title' column with mode value
if mode_title is not None:
    rejected_df.loc[:, 'title'] = mode_title

rejected_df.sample(5)
# Out:
#               id prefix              name title                   email  \
# 4327088   194798    Dr.      Tracey Russo    MD      fsmith@example.com
# 1187866  4249191    Dr.     Alicia Wilson    MD    amanda54@example.net
# 1758812   907359    Dr.     Matthew Morse    MD    tmontoya@example.org
# 4090144  2850634    Dr.  Crystal Chambers    MD   wayneware@example.net
# 4142282  2749182    Dr.   Heather Nielsen    MD  mitchell55@example.com
#
#              country  age
# 4327088           UK   49
# 1187866       Canada   78
# 1758812    Singapore   23
# 4090144  New Zealand   59
# 4142282           UK   23

# %% [markdown]
# #### Merge the modified rejected dataset with accepted dataset

# %%
import pandas as pd
## Code snippet to merge data ~ .. 'outer' is like full join
dqCompletenessTitle = pd.merge(accepted_df,rejected_df,how='outer')

# %%
dqCompletenessTitle.sample(10)
# Out:
#               id prefix             name title                      email  \
# 669908    602649   None  Charles Hawkins  None   youngrebecca@example.net
# 504083    453547   None   Michelle Smith  None      marissa21@example.com
# 3088923  2779447   None     Caitlin Tran  None   michaelgreen@example.org
# 217187    195452   None  Stephanie Rojas  None  katierandolph@example.org
# 1298372  1168148   None    Norman Nguyen  None    justinquinn@example.org
# 3685473  3316334   None      Casey Brown  None   meghanpotter@example.com
# 2974911  2676852   None  Melissa Johnson  None  patrickfisher@example.org
# 899080    808889   None        Ricky Lee  None   ryananderson@example.com
# 2442985  2197874   None     Jeffrey Frey  None    adamosborne@example.com
# 991469    891942   None   Heather Rogers  None        tmiller@example.com
#
#              country  age
# 669908         China   22
# 504083         China   68
# 3088923       France   27
# 217187         India   75
# 1298372    Singapore   36
# 3685473        China   31
# 2974911     Malaysia    5
# 899080   New Zealand   49
# 2442985          USA   31
# 991469       Nigeria   19

# %% [markdown]
# #### Check one of the value in rejected dataset;  "Dr. Rachel Webster MD" instead of "Dr. Rachel Webster"

# %%
# Check if 'title' column contains 'Jr.'
search_string = '3107966'
mask = dqCompletenessTitle['id'].astype(str).str.contains(search_string, case=False)

# Filter DataFrame based on the mask
result = dqCompletenessTitle[mask]

print(result)
# Out:
#               id prefix            name title                   email  \
# 3454063  3107966    Dr.  Rachel Webster    MD  johnspears@example.com
# 3454064  3107966    Dr.  Rachel Webster    MD  johnspears@example.com
#
#           country  age
# 3454063  Malaysia   41
# 3454064  Malaysia   41

# %% [markdown]
# #### Now, drop prefix column

# %%
# Drop the 'Prefix' column
df_modified = dqCompletenessTitle.drop('prefix', axis =1)

# %%
df_modified.sample(10)
# Out:
#               id             name title                         email  \
# 3143725  2828849    Anthony Bates  None            jill65@example.net
# 3006159  2704913       Holly Wang  None             lrice@example.org
# 649658    584446      Lisa Chavez  None         rebecca11@example.org
# 1777559  1599268   George Schmitt  None         tinalewis@example.org
# 2735972  2461815        Jake Pena  None     tiffanyrhodes@example.net
# 187468    168722  Jennifer Taylor  None    mitchelljoseph@example.net
# 4854568  4369039    Russell Patel  None       nathaniel97@example.com
# 526328    473532     Kenneth Hall  None     rachelhouston@example.org
# 528866    475808   William Martin  None  poncechristopher@example.org
# 578022    519925      Nicole Barr  None           amber92@example.org
#
#            country  age
# 3143725     France    5
# 3006159         UK   38
# 649658       China   41
# 1777559        USA   73
# 2735972    Germany   41
# 187468       China  100
# 4854568     Canada   14
# 526328         USA   90
# 528866   Australia   44
# 578022       India   12

# %%
df_modified.shape
# Out:
# (5000000, 6)

# %% [markdown]
# # 2. Consistency for 'email' column
# 1. Split 'email' column into 'email_ID' and 'domain'
# 2. Filter 'email_ID' into accepted and rejected (to ensure all 'email_id' is *alphabetic* only)
# 3. Modify rejected 'email_ID' value (alphanumeric -> alphabet ONLY ; eg: joshua91 -> joshua)
# 4. Merge modified rejected with accepted = total rows ; **Consistency of email column is achieved**

# %% [markdown]
# - Continue from **Completeness** variable
# - Make a copy
# - Check shape before and after copy

# %%
df_modified.shape # use variable from Completeness part
# Out:
# (5000000, 6)

# %%
df_new = df_modified.copy()

# %%
df_new.shape
# Out:
# (5000000, 6)

# %% [markdown]
# #### Split email into 3 columns ('email_id', 'domain', 'TLD')

# %%
# identify and split email into 2 columns
import re

# Function to separate email into username, domain with @, and TLD
def separate_email_df(email):
    email_id, domain = email.split('@')
    domain_name, tld = domain.rsplit('.', 1)
    return pd.Series([email_id, "@" + domain_name,"." + tld], index=['email_id', 'domain', 'TLD'])

# usage with DataFrame:  ** df_new is the variable
df_new[['email_id', 'domain', 'TLD']] = df_new['email'].apply(separate_email_df).apply(pd.Series)

# %%
df_new.sample(10)
# Out:
#               id              name title                          email  \
# 3757454  3381101    Michelle Sharp  None        allenbrenda@example.com
# 4529261  4076173   Cassandra Lewis  None          dayphilip@example.org
# 449084    404056        Paula Case  None  alexanderphillips@example.com
# 2163477  1946424    David Browning  None           gjohnson@example.com
# 2220393  1997581   Alexander Burke    MD           cheryl91@example.net
# 4717126  4245493  Michelle Jenkins  None             hparks@example.net
# 2749295  2473832   Charles Herring  None             mperez@example.org
# 4364200  3927504      Teresa Cohen  None              jkane@example.org
# 891674    802248      Colleen Hall  None     timothyhiggins@example.org
# 181330    163218    Joyce Robinson  None              dan05@example.net
#
#            country  age           email_id    domain   TLD
# 3757454     France   70        allenbrenda  @example  .com
# 4529261         UK   80          dayphilip  @example  .org
# 449084     Germany   83  alexanderphillips  @example  .com
# 2163477     France    6           gjohnson  @example  .com
# 2220393   Malaysia   76           cheryl91  @example  .net
# 4717126   Malaysia   53             hparks  @example  .net
# 2749295  Australia    3             mperez  @example  .org
# 4364200   Malaysia   79              jkane  @example  .org
# 891674       India   42     timothyhiggins  @example  .org
# 181330   Singapore   32              dan05  @example  .net

# %%
df_new.shape
# Out:
# (5000000, 9)

# %%
# copy df_new for backup
df_consistency = df_new.copy()

# %%
df_consistency.shape
# Out:
# (5000000, 9)

# %%
df_consistency.sample(5)
# Out:
#               id              name title                     email   country  \
# 3173428  2855536      Joseph Ayala  None   mrichardson@example.org  Malaysia
# 4802935  4322598  Phillip Cummings  None  meganjackson@example.com  Malaysia
# 4189357  3770072     Matthew Davis  None      tfrancis@example.org    Canada
# 4092031  3682583   Timothy Jackson  None    kimberly34@example.net  Malaysia
# 1483075  1334288    Clifford Downs  None     karenbray@example.net   Germany
#
#          age      email_id    domain   TLD
# 3173428   74   mrichardson  @example  .org
# 4802935   48  meganjackson  @example  .com
# 4189357   32      tfrancis  @example  .org
# 4092031   67    kimberly34  @example  .net
# 1483075   98     karenbray  @example  .net

# %% [markdown]
# - Drop 'email' because can be referred from 'email_id', 'domain' and 'TLD'

# %%
df_consistency = df_consistency.drop('email', axis=1)

# %%
df_consistency.sample(3)
# Out:
#               id           name title  country  age email_id    domain   TLD
# 2602768  2341881  Stanley Banks  None       UK   15   amykim  @example  .org
# 2427282  2183719  Teresa Monroe  None  Germany   46  fguzman  @example  .com
# 2987075  2687784   John Holland  None    China   93  billyli  @example  .com

# %% [markdown]
# - Rearrange for readability

# %%
# rearrange columns into 'id', 'name','title', 'email_id', 'domain', 'country', 'age'
rearrange_col = ['id', 'name','title', 'email_id', 'domain', 'TLD', 'country', 'age']

# Reassign to new_df_2 with the desired column
df_consistency = df_consistency[rearrange_col]

# %%
df_consistency.sample(10)
# Out:
#               id               name title           email_id    domain   TLD  \
# 686333    617433        Sarah Cline  None          kingbrian  @example  .org
# 4917117  4425381   Gregory Williams  None  sandovalelizabeth  @example  .com
# 51814      46657      Chris Johnson  None      medinamelissa  @example  .com
# 3016854  2714520      Dustin Davies  None         lijennifer  @example  .com
# 511863    460529      Thomas Morris  None            paige55  @example  .net
# 1199404  1079029  Kimberly Williams  None           dmarquez  @example  .net
# 1170521  1052932         Brian Page  None           robert56  @example  .com
# 2267512  2039956      Lisa Peterson  None          klawrence  @example  .net
# 4849040  4364059       Matthew Lowe  None        michaelrice  @example  .com
# 1626103  1462967     Michael Torres  None          douglas56  @example  .com
#
#              country  age
# 686333     Singapore   58
# 4917117     Malaysia   48
# 51814         France   38
# 3016854        China   56
# 511863         India   37
# 1199404     Malaysia   60
# 1170521  New Zealand   19
# 2267512        China   83
# 4849040       France   73
# 1626103        India    3

# %% [markdown]
# #### Working on *consistency* of 'email_id' column
# - accepted = combination of Fname + Lname lowercase
# - rejected = contains **numerical value**
# * seperate into accepted , rejected email_id

# %%
# source : df_consistency ; seperate accepted, rejected

# Function to check if email_id is alphabet only
def is_alphabetic(email):
    return email.replace('@', '').isalpha()

# Apply the function and split the DataFrame
accepted_consistency = df_consistency[df_consistency['email_id'].apply(is_alphabetic)]  ## accepted
rejected_consistency = df_consistency[~df_consistency['email_id'].apply(is_alphabetic)] ## rejected

# %%
accepted_consistency.shape
# Out:
# (3750360, 8)

# %%
rejected_consistency.shape
# Out:
# (1249640, 8)

# %%
# sample accepted
accepted_consistency.sample(5)
# Out:
#               id                name title       email_id    domain   TLD  \
# 2662486  2395607      Rebecca Thomas  None  davidmcdaniel  @example  .net
# 525875    473125      Emily Martinez  None   mendezleslie  @example  .org
# 4552835  4097400  Michelle Rodriguez  None  monicastewart  @example  .com
# 3489453  3139860           Lisa West  None   rodriguezamy  @example  .org
# 4443709  3999051   Alexander Pearson  None       kjackson  @example  .net
#
#            country  age
# 2662486     Canada   51
# 525875   Australia   10
# 4552835      China   14
# 3489453      China   53
# 4443709      China   55

# %%
rejected_consistency.sample(5)
# Out:
#               id                name title   email_id    domain   TLD  \
# 3796443  3416204  Christina Mcdaniel  None  madison21  @example  .com
# 3971989  3574343         Jack Nelson  None    lucas87  @example  .org
# 2037689  1833219      Steven Bradley  None   daniel23  @example  .com
# 3872166  3484452      Jeremiah Lucas  None   shelby06  @example  .net
# 1177947  1059638   Christopher Brown  None     lisa78  @example  .com
#
#            country  age
# 3796443   Malaysia   30
# 3971989         UK   11
# 2037689      India   15
# 3872166         UK   14
# 1177947  Australia   33

# %% [markdown]
# - accepted_consistency + rejected_consistency = total of rows before splitting (5 Million)

# %% [markdown]
# #### Modify rejected dataframe:
# discard numerical value from the 'email_id' string, and keep alphabetical string ONLY ; example-> Joshua91 ==> Joshua

# %%
# Modify values in 'email_id'
# Define a function to modify the username
def modify_email(email_id):
    # Check if the username contains numerical characters
    if any(char.isdigit() for char in email_id):
        # Remove numerical characters
        modified_email = ''.join(filter(lambda x: not x.isdigit(), email_id))
        return modified_email
    else:
        return email_id

# Apply the function to the 'username' column
rejected_consistency['email_id'] = rejected_consistency['email_id'].apply(modify_email)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11952\897668353.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected_consistency['email_id'] = rejected_consistency['email_id'].apply(modify_email)

# %%
rejected_consistency.sample(10)
# Out:
#               id                 name title   email_id    domain   TLD  \
# 3378832  3040412   Katherine Gonzalez  None    gregory  @example  .org
# 1842972  1658031       Loretta Steele  None   danielle  @example  .com
# 3028977  2725438          Cody Parker  None      jacob  @example  .com
# 1352693  1217094        Pamela Snyder  None      jerry  @example  .org
# 206370    185746          Erik Garcia  None      roger  @example  .com
# 735193    661412       Wesley Whitney  None  stephanie  @example  .org
# 4536285  4082517          Robert Kane  None   veronica  @example  .com
# 1014723   912798         Joshua Nunez  None   victoria  @example  .com
# 2611406  2349695    Jennifer Gonzalez  None    crystal  @example  .org
# 2968690  2671250  Jacqueline Figueroa   PhD       jose  @example  .net
#
#              country  age
# 3378832      Germany   61
# 1842972        India   16
# 3028977           UK    4
# 1352693  New Zealand   12
# 206370       Germany   54
# 735193           USA   99
# 4536285     Malaysia    7
# 1014723    Australia   37
# 2611406           UK   32
# 2968690     Malaysia    1

# %% [markdown]
# #### Merge accepted and rejected dataset
#  *new merged_df called -> merged_consistency

# %%
## Code snippet to merge data ~ ..
merged_consistency = pd.merge(accepted_consistency, rejected_consistency, how='outer')

# %%
merged_consistency.shape
# Out:
# (5000000, 8)

# %%
# copy merged_consistency ### for presentation screenshot
merged_consistency_1 = merged_consistency.copy()

# %%
# merge email id and domain with new variable => new_email
merged_consistency_1['new_email'] = merged_consistency_1['email_id'] + merged_consistency_1['domain']+ merged_consistency_1['TLD']

# %%
# rearrange columns into 'id', 'name','title', 'email_id', 'domain', 'country', 'age'
rearrange_col_mc = ['id', 'name','title', 'new_email','country', 'age']

# Reassign to new_df_2 with the desired column
merged_consistency_1 = merged_consistency_1[rearrange_col_mc]

# %%
print(merged_consistency_1[merged_consistency_1['id'].isin(range(1, 9))].sort_values(by='id', ascending=True))
# Out:
#    id              name title                  new_email      country  age
# 0   1     Gloria Montes  None  amandaspencer@example.org     Malaysia   68
# 1   2  Ricardo Anderson   PhD         justin@example.com  New Zealand   11
# 2   3        Sara Lewis  None      smithjose@example.net      Germany   21
# 3   4    Troy Maldonado  None  allisonmurphy@example.com    Australia   68
# 4   5   Cheyenne Baxter  None      jaredbell@example.org        China   20
# 5   6       David Smith  None         jriley@example.org     Malaysia   22
# 6   6       David Smith  None         jriley@example.org     Malaysia   22
# 7   7       David Lyons  None  freemanjeanne@example.com           UK   78
# 8   8     Tommy Johnson  None          kelly@example.org           UK   31

# %%
merged_consistency.sample(3)
# Out:
#               id            name title       email_id    domain   TLD  \
# 3061930  2755119  Mitchell Avila  None        melissa  @example  .net
# 2705916  2434746     Lisa Rogers  None  boltonrebecca  @example  .org
# 3452448  3106501  David Johnston  None           kday  @example  .com
#
#           country  age
# 3061930   Germany   81
# 2705916  Malaysia   91
# 3452448   Nigeria    5

# %% [markdown]
# # 2.2 Consistency for 'email_domain'
# - convert all top level domain (TLD) '.net','.org','.com'==> .com   **Commercial use**
#
# 1. Split 'email' column into 'email_no_extension' and 'email_extension'  **extension == TLD**
# 2. Apply the extension constraint/condition
# 3. Merge 'email_without_extension' with 'new_extension' as 'modified_email'
# 4. Replace value of column 'email' with 'modified_email' ; and drop the 'modified_email' column

# %%
df_extension = merged_consistency.copy()

# %%
df_extension.shape
# Out:
# (5000000, 8)

# %%
df_extension.sample(3)
# Out:
#               id             name title      email_id    domain   TLD  \
# 3616810  3254459       Judy Smith  None          dana  @example  .com
# 267371    240566    Steven Castro  None  lindarussell  @example  .org
# 1156636  1040379  Catherine Riggs  None         bryan  @example  .org
#
#              country  age
# 3616810          USA   91
# 267371   New Zealand   43
# 1156636       France   39

# %%
# Count the occurrences of each extension in 'modify_extension'
extension_counts = df_extension['TLD'].apply(lambda x: x.split('.')[-1]).value_counts()
print(extension_counts)
# Out:
# TLD
# net    1668773
# com    1665914
# org    1665313
# Name: count, dtype: int64

# %% [markdown]
# ### Provide new extension for "email_without_extension" :
# - Change all TLD into ==> ".com"   **Commercial use**

# %%
def modify_extension(row):
    new_extension = '.com'
    return new_extension

# Create the new 'modify_extension' column
df_extension['new_TLD'] = df_extension.apply(modify_extension, axis=1)

# %%
df_extension.sample(5)
# Out:
#               id           name title            email_id    domain   TLD  \
# 2030223  1826536   Meghan Chase  None              ajones  @example  .com
# 4103181  3692625   Carrie Black  None              ugould  @example  .org
# 3841281  3456603  Jennifer Ruiz  None  solomonchristopher  @example  .org
# 2047013  1841651  Eddie Sanchez  None               skidd  @example  .net
# 1406892  1265778      Amy Lopez  None               xbell  @example  .net
#
#              country  age new_TLD
# 2030223     Malaysia   37    .com
# 4103181     Malaysia   65    .com
# 3841281       France   31    .com
# 2047013           UK   35    .com
# 1406892  New Zealand   27    .com

# %%
# Count the occurrences of each extension in 'modify_extension'
extension_counts_new = df_extension['new_TLD'].apply(lambda x: x.split('.')[-1]).value_counts()
print(extension_counts_new)
# Out:
# new_TLD
# com    5000000
# Name: count, dtype: int64

# %%
# Assign value of column 'TLD' with column 'new_TLD'
df_extension['TLD'] = df_extension['new_TLD']

# %%
df_extension.sample(3)
# Out:
#               id            name title     email_id    domain   TLD  \
# 4607904  4147037  Dennis Gardner  None       bchung  @example  .com
# 280904    252743     Carla Allen  None     adamcook  @example  .com
# 3875674  3487597  Jeffery Morgan  None  davidthomas  @example  .com
#
#            country  age new_TLD
# 4607904  Australia   34    .com
# 280904   Australia   61    .com
# 3875674    Nigeria   23    .com

# %%
# Drop columns
df_extension = df_extension.drop(['new_TLD'], axis=1)

# %%
df_extension.sample(3)
# Out:
#               id            name title   email_id    domain   TLD    country  \
# 2389832  2150089  Kenneth Carter  None    lturner  @example  .com   Malaysia
# 1638741  1474389    Dawn Wallace  None   dvazquez  @example  .com  Singapore
# 2275601  2047242  Kimberly Zhang  None  maryscott  @example  .com         UK
#
#          age
# 2389832   99
# 1638741   68
# 2275601   58

# %%
df_extension_example = df_extension.copy()

# %%
# merge all (email_id, domain, TLD) as ==> 'email'
df_extension_example['email'] = df_extension_example['email_id'] + df_extension_example['domain'] + df_extension_example['TLD']

# %%
#rearrange column
desirecol = ['id','name','title','email','country','age']

df_extension_example = df_extension_example[desirecol]

# %%
print(df_extension_example[df_extension_example['id'].isin(range(1, 9))].sort_values(by='id', ascending=True))
# Out:
#    id              name title                      email      country  age
# 0   1     Gloria Montes  None  amandaspencer@example.com     Malaysia   68
# 1   2  Ricardo Anderson   PhD         justin@example.com  New Zealand   11
# 2   3        Sara Lewis  None      smithjose@example.com      Germany   21
# 3   4    Troy Maldonado  None  allisonmurphy@example.com    Australia   68
# 4   5   Cheyenne Baxter  None      jaredbell@example.com        China   20
# 5   6       David Smith  None         jriley@example.com     Malaysia   22
# 6   6       David Smith  None         jriley@example.com     Malaysia   22
# 7   7       David Lyons  None  freemanjeanne@example.com           UK   78
# 8   8     Tommy Johnson  None          kelly@example.com           UK   31

# %% [markdown]
# - Consistency of email username and email TLD is achieved ('alphabetic', '.com')
# - continue to Accuracy part using variable ==> 'df_extension'

# %% [markdown]
# # 3. Accuracy for relation between column 'name' and 'email'
# - Print out sample, ensure its correctness (rows & columns) before proceeds
# 1. Generate new column "expected_email_id" , based off 'name' column with constraints all lowercase and no whitespace
# 2. Check assumption that 'email_ID' == 'expected_email_id'  ; 19 rows matched with assumption (before deduplication process)
# 3. Seperate/Split 'email_ID' into accepted and rejected
# 4. Modify rejected 'email_ID' by replacing/re-assign value of "expected_email_id" into "email_ID"
# 5. Merge 'modified rejected' and 'accepted' as/for column 'email_ID' ; step 9
# 6. Drop 'expected_email_id' and 'matched' columns  (Step 10)
# 7. Merge 'email_ID' and 'domain' as 'email' column  **Accuracy between name & email is achieved**

# %% [markdown]
# #### Continue from Consistency part

# %%
def clean_name_df(name):
    # Convert the name to lowercase and remove whitespace
    cleaned_name = name.lower().replace(" ", "")
    return cleaned_name

df_extension['expected_email_id'] = df_extension['name'].apply(clean_name_df)

# %%
df_extension.sample(10)
# Out:
#               id               name title        email_id    domain   TLD  \
# 3145666  2830591  Katherine Proctor  None           hpham  @example  .com
# 4590434  4131303      Nancy Shannon  None        ksalazar  @example  .com
# 4926708  4434027         John Gould   DVM  adriananderson  @example  .com
# 3721423  3348698       Robert Blair  None   ruizcatherine  @example  .com
# 2520832  2268135     Joseph Bradley  None         marissa  @example  .com
# 3043534  2738514     Angela Sherman  None  fredmontgomery  @example  .com
# 791995    712510      Laurie Mccall  None          andrew  @example  .com
# 453491    408010       Alex Beltran  None       kmcintosh  @example  .com
# 356389    320579      Melissa Moore  None   fowlerpatrick  @example  .com
# 3285801  2956609        Casey Black  None           james  @example  .com
#
#              country  age expected_email_id
# 3145666        India   12  katherineproctor
# 4590434        India   90      nancyshannon
# 4926708     Malaysia   64         johngould
# 3721423        China   81       robertblair
# 2520832        India   35     josephbradley
# 3043534      Nigeria   61     angelasherman
# 791995   New Zealand   54      lauriemccall
# 453491         India   17       alexbeltran
# 356389       Nigeria   35      melissamoore
# 3285801    Singapore   72        caseyblack

# %%
# rearrange columns into 'id','Name','expected_email_id','email_id', 'Domain', 'country', 'age'
rearrange_col_acc = ['id', 'name', 'title', 'expected_email_id', 'email_id', 'domain', 'TLD' , 'country', 'age']

# Reassign to new_df_2 with the desired column
df_accuracy = df_extension[rearrange_col_acc]

# %%
df_accuracy.sample(5)
# Out:
#               id                name title  expected_email_id  \
# 1107387   996092         Sandra Neal  None         sandraneal
# 4307124  3876195      Miguel Maxwell  None      miguelmaxwell
# 4226249  3803315  Mackenzie Williams  None  mackenziewilliams
# 1519747  1367309        Melissa Rose  None        melissarose
# 1756487  1580357          Dawn Banks  None          dawnbanks
#
#                  email_id    domain   TLD    country  age
# 1107387  fitzgeraldmanuel  @example  .com   Malaysia   21
# 4307124             megan  @example  .com  Australia   93
# 4226249         iodonnell  @example  .com      China   94
# 1519747          benjamin  @example  .com  Singapore   96
# 1756487          michelle  @example  .com    Germany   32

# %% [markdown]
# #### Check for match and compare between expected_email_id (name) and email_id column ;
#  * if matched = 'True', else false ; hence got the accuracy

# %%
# Function to CHECK if email_id matches expected_email_id
def check_match(row):
    return row['expected_email_id'] == row['email_id']

# Add new column to store the value of 'matched'
df_accuracy['matched'] = df_accuracy.apply(check_match, axis=1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11952\780265807.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_accuracy['matched'] = df_accuracy.apply(check_match, axis=1)

# %%
# Count occurrences of True and False in the 'matched' column
matched_counts = df_accuracy['matched'].value_counts()

# Print the counts
print("True count:", matched_counts.get(True, 0))
print("False count:", matched_counts.get(False, 0))
# Out:
# True count: 19
# False count: 4999981

# %% [markdown]
# - Expected result should have True count: 19 (contains duplicate)

# %% [markdown]
# #### Identify accepted (matched) and rejected (unmatched) email id, and seperate/store it in variable

# %%
# Filter the DataFrame to show only rows where 'matched' is True
matched_rows = df_accuracy[df_accuracy['matched']]

# %%
matched_rows.sample(19)
# Out:
#               id               name title expected_email_id          email_id  \
# 421436    379156    Cynthia Johnson  None    cynthiajohnson    cynthiajohnson
# 809935    728620      Sara Gonzalez  None      saragonzalez      saragonzalez
# 1038441   934077     Patrick Warren  None     patrickwarren     patrickwarren
# 4050444  3645070      Robert Miller  None      robertmiller      robertmiller
# 4251192  3825729  Jennifer Williams  None  jenniferwilliams  jenniferwilliams
# 494478    444892    Matthew Johnson  None    matthewjohnson    matthewjohnson
# 2465935  2218632     Brandon Wilson  None     brandonwilson     brandonwilson
# 2801327  2520629    Angela Williams  None    angelawilliams    angelawilliams
# 1038440   934077     Patrick Warren  None     patrickwarren     patrickwarren
# 3648857  3283256    Amanda Phillips  None    amandaphillips    amandaphillips
# 2465936  2218632     Brandon Wilson  None     brandonwilson     brandonwilson
# 1042841   938029      James Sanchez  None      jamessanchez      jamessanchez
# 1042840   938029      James Sanchez  None      jamessanchez      jamessanchez
# 4238916  3814702       Andrew Moore  None       andrewmoore       andrewmoore
# 4050443  3645070      Robert Miller  None      robertmiller      robertmiller
# 3961527  3564905        Holly Dixon  None        hollydixon        hollydixon
# 494477    444892    Matthew Johnson  None    matthewjohnson    matthewjohnson
# 2872056  2584258       Robert Lewis  None       robertlewis       robertlewis
# 4251193  3825729  Jennifer Williams  None  jenniferwilliams  jenniferwilliams
#
#            domain   TLD      country  age  matched
# 421436   @example  .com    Australia   37     True
# 809935   @example  .com        India   64     True
# 1038441  @example  .com          USA   90     True
# 4050444  @example  .com          USA   60     True
# 4251192  @example  .com  New Zealand    4     True
# 494478   @example  .com     Malaysia   78     True
# 2465935  @example  .com     Malaysia   58     True
# 2801327  @example  .com      Germany    5     True
# 1038440  @example  .com          USA   90     True
# 3648857  @example  .com      Germany    1     True
# 2465936  @example  .com     Malaysia   58     True
# 1042841  @example  .com    Australia   88     True
# 1042840  @example  .com    Australia   88     True
# 4238916  @example  .com  New Zealand   24     True
# 4050443  @example  .com          USA   60     True
# 3961527  @example  .com        China  100     True
# 494477   @example  .com     Malaysia   78     True
# 2872056  @example  .com        China   27     True
# 4251193  @example  .com  New Zealand    4     True

# %%
matched_rows.shape
# Out:
# (19, 10)

# %%
# Filter the DataFrame to show only rows where 'matched' is False
unmatched_rows = df_accuracy[~df_accuracy['matched']]

# Display the unmatched rows
unmatched_rows.sample(10)
# Out:
#               id               name title expected_email_id        email_id  \
# 615748    553884        Lisa Harris  None        lisaharris          ymoore
# 4086013  3677160         Gregory Li  None         gregoryli    barnesalbert
# 4920110  4428082  Nicholas Schaefer  None  nicholasschaefer         richard
# 2628500  2365040     Cheryl Johnson  None     cheryljohnson     douglashaas
# 1089697   980230    Nicholas Rogers  None    nicholasrogers   harriswilliam
# 3417699  3075270     Tara Contreras  None     taracontreras  patricialawson
# 972958    875239       Lisa Herrera  None       lisaherrera            dawn
# 160163    144139       Brian Taylor  None       briantaylor      qwilkinson
# 3883298  3494452   Jessica Gonzales  None   jessicagonzales          daniel
# 4556381  4100586      Colleen Costa  None      colleencosta     brooksmegan
#
#            domain   TLD    country  age  matched
# 615748   @example  .com      China   48    False
# 4086013  @example  .com   Malaysia   39    False
# 4920110  @example  .com    Nigeria   60    False
# 2628500  @example  .com   Malaysia   93    False
# 1089697  @example  .com    Germany   23    False
# 3417699  @example  .com         UK   55    False
# 972958   @example  .com  Australia   20    False
# 160163   @example  .com  Australia   72    False
# 3883298  @example  .com      India    9    False
# 4556381  @example  .com     Canada   96    False

# %%
unmatched_rows.shape
# Out:
# (4999981, 10)

# %% [markdown]
# #### Modifying the rejected/unmatched rows to achieve consistency and accuracy of rows

# %%
# For consistency and accuracy, replace 'email_id' with 'expected_email_id'
unmatched_rows['email_id'] = unmatched_rows['expected_email_id']

# check sample
unmatched_rows.sample(5)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11952\2521713817.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unmatched_rows['email_id'] = unmatched_rows['expected_email_id']
#               id               name title expected_email_id          email_id  \
# 4077819  3669754         Lisa Ortiz  None         lisaortiz         lisaortiz
# 1739620  1565174     Monica Gregory  None     monicagregory     monicagregory
# 3820344  3437752    Tracy Rasmussen  None    tracyrasmussen    tracyrasmussen
# 2245051  2019740  Shannon Fernandez  None  shannonfernandez  shannonfernandez
# 865832    778966      Jill Delacruz  None      jilldelacruz      jilldelacruz
#
#            domain   TLD      country  age  matched
# 4077819  @example  .com      Germany   61    False
# 1739620  @example  .com     Malaysia   40    False
# 3820344  @example  .com        China    5    False
# 2245051  @example  .com  New Zealand   55    False
# 865832   @example  .com     Malaysia   74    False

# %% [markdown]
# #### Merge the matched rows and fixed unmatched rows

# %%
## Code snippet to merge data ~ ..
merged_df = pd.merge(matched_rows, unmatched_rows, how='outer')

# %%
# check shape of newly merged df, make sure 5 Million rows
merged_df.shape
# Out:
# (5000000, 10)

# %%
merged_df.sample(5)
# Out:
#               id         name title expected_email_id    email_id    domain  \
# 1004547   903648  Linda Sloan  None        lindasloan  lindasloan  @example
# 4272690  3845129  Mark Carney  None        markcarney  markcarney  @example
# 2353448  2117274  Jordan Cole  None        jordancole  jordancole  @example
# 2837448  2553166   Janet Beck  None         janetbeck   janetbeck  @example
# 773100    695495  Alicia Wade  None        aliciawade  aliciawade  @example
#
#           TLD    country  age  matched
# 1004547  .com   Malaysia   59    False
# 4272690  .com  Singapore   39    False
# 2353448  .com   Malaysia   67    False
# 2837448  .com    Germany   12    False
# 773100   .com   Malaysia    6    False

# %% [markdown]
# #### Drop 'expected_email_id' and 'matched' columns

# %%
# Drop columns
new_merged_df = merged_df.drop(['expected_email_id', 'matched'], axis=1)

# %%
# check sample after drop table
new_merged_df.sample(5)
# Out:
#               id              name title         email_id    domain   TLD  \
# 3597778  3237321   Franklin Parker  None   franklinparker  @example  .com
# 3693363  3323407  William Williams  None  williamwilliams  @example  .com
# 4209296  3788031  Kathryn Stafford  None  kathrynstafford  @example  .com
# 128994    116145    Kristin Warner  None    kristinwarner  @example  .com
# 4412830  3971314    Amanda Edwards  None    amandaedwards  @example  .com
#
#           country  age
# 3597778       USA   30
# 3693363        UK   76
# 4209296  Malaysia   49
# 128994        USA   40
# 4412830    France   69

# %%
# create copy of 'new_merged_df'  
new_merged_df_example = new_merged_df.copy()

# %%
# merge (email_id, domain, TLD) => 'email'
new_merged_df_example['email'] = new_merged_df_example['email_id'] + new_merged_df_example['domain'] + new_merged_df_example['TLD']

# %%
new_merged_df_example.sample(3)
# Out:
#               id               name title          email_id    domain   TLD  \
# 3813842  3431883  Caroline Schwartz  None  carolineschwartz  @example  .com
# 3823493  3440595       Stacey Brown  None       staceybrown  @example  .com
# 134644    121204         Amy Murphy  None         amymurphy  @example  .com
#
#            country  age                         email
# 3813842  Australia   76  carolineschwartz@example.com
# 3823493   Malaysia   77       staceybrown@example.com
# 134644     Nigeria   17         amymurphy@example.com

# %%
# rearrange columns into 'id', 'name','title', 'email_id', 'domain', 'country', 'age'
rearrange_col_nm = ['id','name','title','email','country','age']

# Reassign to new_df_2 with the desired column
new_merged_df_example = new_merged_df_example[rearrange_col_nm]

# %%
print(new_merged_df_example[new_merged_df_example['id'].isin(range(1, 9))].sort_values(by='id', ascending=True))
# Out:
#    id              name title                        email      country  age
# 0   1     Gloria Montes  None     gloriamontes@example.com     Malaysia   68
# 1   2  Ricardo Anderson   PhD  ricardoanderson@example.com  New Zealand   11
# 2   3        Sara Lewis  None        saralewis@example.com      Germany   21
# 3   4    Troy Maldonado  None    troymaldonado@example.com    Australia   68
# 4   5   Cheyenne Baxter  None   cheyennebaxter@example.com        China   20
# 5   6       David Smith  None       davidsmith@example.com     Malaysia   22
# 6   6       David Smith  None       davidsmith@example.com     Malaysia   22
# 7   7       David Lyons  None       davidlyons@example.com           UK   78
# 8   8     Tommy Johnson  None     tommyjohnson@example.com           UK   31

# %% [markdown]
# #### Notice the name and email is accurate, however there are problems with duplication
# - continue working with variable 'new_merged_df'

# %%
new_merged_df.sample(3)
# Out:
#               id           name title      email_id    domain   TLD  country  \
# 2830891  2547252     Anne Smith  None     annesmith  @example  .com       UK
# 3436904  3092522  Jacob Hoffman  None  jacobhoffman  @example  .com  Nigeria
# 3905811  3514732   Jeremy Gates  None   jeremygates  @example  .com    India
#
#          age
# 2830891   48
# 3436904   55
# 3905811   22

# %% [markdown]
# ## id is added into the 'email_id' and 'domain' to mitigate the duplication issues and achieve uniqueness as well

# %%
# Merge 'email_id', 'id' and 'domain' columns into a new column 'email' (added ID for uniqueness)
new_merged_df['email'] = new_merged_df['email_id'] + '_' + new_merged_df['id'].astype(str)+ new_merged_df['domain'] + new_merged_df['TLD']

# %%
new_merged_df.sample(3)
# Out:
#               id               name title          email_id    domain   TLD  \
# 1562237  1405579  Michael Nicholson  None  michaelnicholson  @example  .com
# 2961277  2664558      William Hayes  None      williamhayes  @example  .com
# 82441      74203     Jennifer Smith  None     jennifersmith  @example  .com
#
#            country  age                                 email
# 1562237  Singapore   43  michaelnicholson_1405579@example.com
# 2961277      India    9      williamhayes_2664558@example.com
# 82441     Malaysia   22       jennifersmith_74203@example.com

# %%
# Drop the original 'email_id' and 'domain' columns
new_merged_df = new_merged_df.drop(['email_id', 'domain', 'TLD'], axis=1)

# %%
new_merged_df.sample(3)
# Out:
#               id          name title    country  age  \
# 3019221  2716670   Victor Duke  None      China   35
# 4520801  4068530   Lynn Abbott  None  Australia   10
# 4797826  4318005  Andrew Gomez  None   Malaysia   63
#
#                                    email
# 3019221   victorduke_2716670@example.com
# 4520801   lynnabbott_4068530@example.com
# 4797826  andrewgomez_4318005@example.com

# %%
# state the desired column 
desired_cols_acc = ['id','name','title','email','country','age']

new_merged_df = new_merged_df[desired_cols_acc]

# %%
new_merged_df.sample(3)
# Out:
#               id              name title                                email  \
# 767310    690264      Kathy Flores  None       kathyflores_690264@example.com
# 4888461  4399572       Julian Pena  None       julianpena_4399572@example.com
# 3465335  3118077  Janice Mcfarland    MD  janicemcfarland_3118077@example.com
#
#            country  age
# 767310     Germany   30
# 4888461  Singapore   64
# 3465335         UK   39

# %%
print(new_merged_df[new_merged_df['id'].isin(range(1, 9))].sort_values(by='id', ascending=True))
# Out:
#    id              name title                          email      country  age
# 0   1     Gloria Montes  None     gloriamontes_1@example.com     Malaysia   68
# 1   2  Ricardo Anderson   PhD  ricardoanderson_2@example.com  New Zealand   11
# 2   3        Sara Lewis  None        saralewis_3@example.com      Germany   21
# 3   4    Troy Maldonado  None    troymaldonado_4@example.com    Australia   68
# 4   5   Cheyenne Baxter  None   cheyennebaxter_5@example.com        China   20
# 5   6       David Smith  None       davidsmith_6@example.com     Malaysia   22
# 6   6       David Smith  None       davidsmith_6@example.com     Malaysia   22
# 7   7       David Lyons  None       davidlyons_7@example.com           UK   78
# 8   8     Tommy Johnson  None     tommyjohnson_8@example.com           UK   31

# %% [markdown]
# * Continue next process

# %% [markdown]
# ## Validity Process - Scenario 1: Validity based on title and age
# - Notices that some of the title are still exists at 1 years old whih is not valid.
# - Feedback shows that average age to have doctor title
#     - DDS, DVM and PhD : 26 Years old
#     - MD : 33 years old, due to additional 3-8 years of residency
# - Therefore,
#    - Rejected dataset - Those who are younger than 26 years old for DDS, DVM and PhD & younger than 33 years old for MD
#    - Accepted dataset - Those who do not meet the requirements

# %%
# Check if 'title' column contains 'Jr.'
search_string = 'DVM'
mask = new_merged_df['title'].astype(str).str.contains(search_string, case=False)

# Filter DataFrame based on the mask
result = new_merged_df[mask]

print(result)
# Out:
#               id                name title  \
# 10            10     Benjamin Joseph   DVM
# 33            32           Mike Cook   DVM
# 373          343        Sherry Avery   DVM
# 412          379        Janet Dennis   DVM
# 413          379        Janet Dennis   DVM
# ...          ...                 ...   ...
# 4999045  4499138  Catherine Gonzalez   DVM
# 4999046  4499138  Catherine Gonzalez   DVM
# 4999129  4499214      Bridget Norman   DVM
# 4999437  4499496         James Brown   DVM
# 4999740  4499769        Diane Wilson   DVM
#
#                                          email      country  age
# 10               benjaminjoseph_10@example.com      Germany   98
# 33                     mikecook_32@example.com  New Zealand   67
# 373                sherryavery_343@example.com           UK   61
# 412                janetdennis_379@example.com           UK    5
# 413                janetdennis_379@example.com           UK    5
# ...                                        ...          ...  ...
# 4999045  catherinegonzalez_4499138@example.com       France   48
# 4999046  catherinegonzalez_4499138@example.com       France   48
# 4999129      bridgetnorman_4499214@example.com           UK   65
# 4999437         jamesbrown_4499496@example.com        India   64
# 4999740        dianewilson_4499769@example.com          USA   65
#
# [17546 rows x 6 columns]

# %%
# copy df_new for backup
new_merged_df_copy = new_merged_df.copy()

# %% [markdown]
# ### Dividing accepted dataset and rejected dataset
#
# ##### Rejected dataset
# The dataset contains of invalid data which;
# 1. Younger than 26 years old for DDS, DVM and PhD
# 2. Younger than 33 years old for MD
#
#
# ##### Accepted Dataset
# The dataset contains of valid data which;
# 1. Those who do not meet the requirement

# %%
# Create masks for different titles
has_DDS_DVM_PhD = new_merged_df_copy['title'].str.contains(r'(DDS|DVM|PhD)', na=False)
has_MD = new_merged_df_copy['title'].str.contains(r'MD', na=False)

# Define rejected condition based on age and title
rejected_condition = (
    ((new_merged_df_copy['age'] < 26) & (has_DDS_DVM_PhD)) |                   ## df_extension_copy
    (( new_merged_df_copy['age'] < 33) & (has_MD))
)

# Filter the DataFrame for rejected rows based on the rejected condition
rejected_filter = new_merged_df_copy[rejected_condition]

# Define accepted condition as the negation of the rejected condition
acceptable_condition = ~rejected_condition

# Filter the DataFrame based on the acceptable condition
accept_filter =  new_merged_df_copy[acceptable_condition]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11952\880087165.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   has_DDS_DVM_PhD = new_merged_df_copy['title'].str.contains(r'(DDS|DVM|PhD)', na=False)

# %%
# Print filtered DataFrame
print("Accepted DataFrame:")
accept_filter.sample(5)
# Out:
# Accepted DataFrame:
#               id              name title                               email  \
# 966818    869689      David Rogers  None      davidrogers_869689@example.com
# 3737217  3362932    Christian Levy  None   christianlevy_3362932@example.com
# 749025    673828      Linda Vaughn  None      lindavaughn_673828@example.com
# 141044    126941  Steven Rodriguez  None  stevenrodriguez_126941@example.com
# 2866317  2579102   Hayley Lawrence  None  hayleylawrence_2579102@example.com
#
#            country  age
# 966818     Nigeria   70
# 3737217   Malaysia   95
# 749025   Australia   21
# 141044   Singapore   62
# 2866317   Malaysia   32

# %%
print("Rejected DataFrame:")
rejected_filter.sample(15)
# Out:
# Rejected DataFrame:
#               id              name title                                email  \
# 1998424  1797894     Gregory Riley    MD     gregoryriley_1797894@example.com
# 3143360  2828524     Melissa Smith    MD     melissasmith_2828524@example.com
# 401210    360901   Elizabeth Mckee    MD    elizabethmckee_360901@example.com
# 4446692  4001751  Jennifer Stewart    MD  jenniferstewart_4001751@example.com
# 784894    706128    Jack Zimmerman   DVM     jackzimmerman_706128@example.com
# 1672145  1504505    Yolanda Booker    MD    yolandabooker_1504505@example.com
# 1910291  1718527     Kristi Garcia   DDS     kristigarcia_1718527@example.com
# 4240874  3816480      Robert Adams    MD      robertadams_3816480@example.com
# 722464    649985      Sheri Bryant    MD       sheribryant_649985@example.com
# 1285333  1156377   Heather Mueller    MD   heathermueller_1156377@example.com
# 304860    274221      Alyssa Myers   DDS       alyssamyers_274221@example.com
# 973700    875913      April Bailey    MD       aprilbailey_875913@example.com
# 3437234  3092806        James Wade    MD        jameswade_3092806@example.com
# 1515639  1363618        Adam Black   DDS        adamblack_1363618@example.com
# 4361961  3925483         Lisa Berg    MD         lisaberg_3925483@example.com
#
#              country  age
# 1998424       France   19
# 3143360       France    5
# 401210     Singapore   19
# 4446692      Germany   20
# 784894       Nigeria   19
# 1672145        China    7
# 1910291       France    9
# 4240874    Australia   10
# 722464            UK   18
# 1285333    Singapore    4
# 304860   New Zealand   25
# 973700       Nigeria   20
# 3437234           UK   15
# 1515639      Nigeria    8
# 4361961          USA   27

# %%
accept_filter.shape
# Out:
# (4963460, 6)

# %%
rejected_filter.shape
# Out:
# (36540, 6)

# %%
accept_filter.sample(3)
# Out:
#               id              name title                                email  \
# 4402533  3962000  Paula Williamson  None  paulawilliamson_3962000@example.com
# 3744644  3369632    Benjamin Marsh  None    benjaminmarsh_3369632@example.com
# 3619848  3257200     Adrian Henson  None     adrianhenson_3257200@example.com
#
#            country  age
# 4402533      China   76
# 3744644  Australia   99
# 3619848     France   90

# %%
# Check the minimum value in the 'title' column
min_age = rejected_filter['age'].max()

print("Minimum age in the 'title' column:", min_age)
# Out:
# Minimum age in the 'title' column: 32

# %% [markdown]
# #### Validate the Accepted dataset using  'search_string' with accepted row

# %%
# Check if 'title' column contains 'Dustin Miller.'
search_string = 'Dustin Miller'
mask = accept_filter['name'].astype(str).str.contains(search_string, case=False)

# Filter DataFrame based on the mask
result = accept_filter[mask]

# %%
result.sample(20)
# Out:
#               id           name title                             email  \
# 2281411  2052466  Dustin Miller  None  dustinmiller_2052466@example.com
# 3555765  3199523  Dustin Miller  None  dustinmiller_3199523@example.com
# 2970693  2673048  Dustin Miller  None  dustinmiller_2673048@example.com
# 1920489  1727738  Dustin Miller  None  dustinmiller_1727738@example.com
# 1325589  1192669  Dustin Miller  None  dustinmiller_1192669@example.com
# 240501    216414  Dustin Miller  None   dustinmiller_216414@example.com
# 194399    174968  Dustin Miller   DDS   dustinmiller_174968@example.com
# 3831902  3448157  Dustin Miller  None  dustinmiller_3448157@example.com
# 2354833  2118512  Dustin Miller  None  dustinmiller_2118512@example.com
# 2526995  2273677  Dustin Miller  None  dustinmiller_2273677@example.com
# 1357749  1221648  Dustin Miller  None  dustinmiller_1221648@example.com
# 2176321  1957943  Dustin Miller  None  dustinmiller_1957943@example.com
# 3957878  3561612  Dustin Miller   PhD  dustinmiller_3561612@example.com
# 4791793  4312564  Dustin Miller  None  dustinmiller_4312564@example.com
# 1163163  1046301  Dustin Miller  None  dustinmiller_1046301@example.com
# 4194559  3774751  Dustin Miller  None  dustinmiller_3774751@example.com
# 2132857  1918869  Dustin Miller  None  dustinmiller_1918869@example.com
# 2931768  2637987  Dustin Miller  None  dustinmiller_2637987@example.com
# 2899307  2608782  Dustin Miller  None  dustinmiller_2608782@example.com
# 1586702  1427604  Dustin Miller  None  dustinmiller_1427604@example.com
#
#              country  age
# 2281411  New Zealand   82
# 3555765  New Zealand   22
# 2970693       Canada   35
# 1920489     Malaysia   48
# 1325589        India    2
# 240501         India   70
# 194399       Nigeria   33
# 3831902       Canada   56
# 2354833  New Zealand   39
# 2526995  New Zealand   99
# 1357749     Malaysia   81
# 2176321       France   68
# 3957878      Germany   47
# 4791793     Malaysia   46
# 1163163     Malaysia   38
# 4194559    Australia   97
# 2132857       France   22
# 2931768       Canada   88
# 2899307       Canada   22
# 1586702     Malaysia   68

# %% [markdown]
# #### Modify the rejected dataset
# - Replace all rejected value into "N/A"

# %%
rejected_filter.shape
# Out:
# (36540, 6)

# %%
# Create a condition to identify rows for replacement
condition = (rejected_filter['title'].notnull())

# Replace values in 'title' column with "N/A" based on the condition
rejected_filter.loc[condition, 'title'] = 'N/A'

# %%
rejected_filter.sample(5)
# Out:
#               id            name title                              email  \
# 670845    603495      Ian Nelson   N/A       iannelson_603495@example.com
# 2545092  2289949   Cristina Ward   N/A   cristinaward_2289949@example.com
# 3346707  3011560   Ashley Ingram   N/A   ashleyingram_3011560@example.com
# 3613167  3251157       Amy Dixon   N/A       amydixon_3251157@example.com
# 4010487  3609092  Jonathan Brown   N/A  jonathanbrown_3609092@example.com
#
#           country  age
# 670845    Germany   26
# 2545092  Malaysia    3
# 3346707  Malaysia   10
# 3613167        UK    8
# 4010487    France   23

# %% [markdown]
# #### Merged modified rejected with accepted value

# %%
import pandas as pd
## Code snippet to merge data ~ .. 'outer' is like full join
dqValidity1 = pd.merge(rejected_filter,accept_filter,how='outer')

# %%
dqValidity1.sample(10)
# Out:
#               id                name title  \
# 3882409  3493645  Christian Martinez  None
# 4337958  3903932        Sarah Reilly  None
# 324723    292082       Lisa Sheppard  None
# 32171      28994       Nichole Evans  None
# 4305676  3874905    Nicholas Johnson  None
# 1026066   922948          Renee Cook  None
# 3087348  2778005       Steven Maddox  None
# 2504361  2253276            Paul Fry  None
# 2334234  2099986       Laura Shields  None
# 1693606  1523855        Emily Durham  None
#
#                                          email    country  age
# 3882409  christianmartinez_3493645@example.com   Malaysia   63
# 4337958        sarahreilly_3903932@example.com     France   77
# 324723         lisasheppard_292082@example.com     France   58
# 32171           nicholeevans_28994@example.com      China   36
# 4305676    nicholasjohnson_3874905@example.com     Canada    3
# 1026066           reneecook_922948@example.com     France   55
# 3087348       stevenmaddox_2778005@example.com  Australia   53
# 2504361            paulfry_2253276@example.com   Malaysia    2
# 2334234       laurashields_2099986@example.com   Malaysia    5
# 1693606        emilydurham_1523855@example.com   Malaysia   58

# %% [markdown]
# ## Validity Process - Scenario 2: Validity based on email and age
#    - Rejected dataset - Those who are younger than 13 years old
#    - Accepted dataset - Those who do not meet the requirements

# %% [markdown]
# ### Dividing accepted dataset and rejected dataset
#
# ##### Rejected dataset
# The dataset contains of invalid data which;
# 1. Those who are younger than 13 years old
#
#
# ##### Accepted Dataset
# The dataset contains of valid data which;
# 1. Those who do not meet the requirement

# %%
# Define rejected & accepted condition based on age and title
rejected_condition = dqValidity1['age'] <= 12
accepted_condition = dqValidity1['age'] > 12

# Filter the DataFrame for rejected rows based on the rejected condition
rejected_filter = dqValidity1[rejected_condition]

# Filter the DataFrame based on the acceptable condition
accept_filter = dqValidity1[accepted_condition]

# %%
print("Rejected DataFrame:")
rejected_filter.sample(10)
# Out:
# Rejected DataFrame:
#               id            name title                              email  \
# 3696988  3326665   Judith Walker  None   judithwalker_3326665@example.com
# 1165393  1048326      Jacob Kerr  None      jacobkerr_1048326@example.com
# 2764346  2487385     Brent Lopez  None     brentlopez_2487385@example.com
# 1880950  1692151   Samantha Bell  None   samanthabell_1692151@example.com
# 4305912  3875118   Haley Ramirez  None   haleyramirez_3875118@example.com
# 252928    227622  Katherine Snow  None   katherinesnow_227622@example.com
# 4893515  4404093   Sarah Johnson  None   sarahjohnson_4404093@example.com
# 855901    770027    Cory Pollard  None     corypollard_770027@example.com
# 3461152  3114341  Shannon Wilson   N/A  shannonwilson_3114341@example.com
# 3900832  3510250   Valerie Banks  None   valeriebanks_3510250@example.com
#
#              country  age
# 3696988        China    8
# 1165393       Canada    1
# 2764346        India    7
# 1880950  New Zealand    6
# 4305912           UK    8
# 252928         India    1
# 4893515    Australia    9
# 855901      Malaysia   12
# 3461152      Nigeria    3
# 3900832       France   12

# %%
print("Accepted DataFrame:")
accept_filter.sample(10)
# Out:
# Accepted DataFrame:
#               id               name title  \
# 2941485  2646768     Michelle Burke  None
# 3537242  3182887     Yvonne Johnson  None
# 448936    403927       Debbie Perez    MD
# 4387320  3948305      Daniel Wilson  None
# 1711119  1539545   Elizabeth Bryant  None
# 4255750  3829850       Arthur Adams  None
# 1030060   926537     Deanna Bennett  None
# 4295334  3865588  Monica Montgomery  None
# 1216027  1094058       Jason Miller  None
# 3107973  2796591        Laura Brown  None
#
#                                         email      country  age
# 2941485     michelleburke_2646768@example.com        India   52
# 3537242     yvonnejohnson_3182887@example.com           UK   51
# 448936         debbieperez_403927@example.com    Singapore   43
# 4387320      danielwilson_3948305@example.com           UK   46
# 1711119   elizabethbryant_1539545@example.com          USA   72
# 4255750       arthuradams_3829850@example.com        India   94
# 1030060      deannabennett_926537@example.com  New Zealand   82
# 4295334  monicamontgomery_3865588@example.com    Australia   46
# 1216027       jasonmiller_1094058@example.com    Singapore   98
# 3107973        laurabrown_2796591@example.com        China   77

# %% [markdown]
# ### Modified Rejected dataset
# - Replace email value with "N/A" for those younger than 12 years old

# %%
# Create a condition to identify rows for replacement
# condition = rejected_filter[(rejected_filter['age'] <= 12) & (rejected_filter['email'].str.contains('@'))]
condition = (rejected_filter['age'] <= 12)

# Replace values in 'title' column with "N/A" based on the condition
rejected_filter.loc[condition, 'email'] = 'N/A'

# %%
print("Updated DataFrame:")
rejected_filter.sample(10)
# Out:
# Updated DataFrame:
#               id              name title email      country  age
# 4819469  4337506    Jessica Hunter  None   N/A        India    2
# 4978853  4480976    Benjamin Banks   N/A   N/A      Nigeria    4
# 1505097  1354129  Elizabeth Walker  None   N/A     Malaysia    9
# 4513381  4061857        Karen Horn  None   N/A     Malaysia   10
# 474572    427025  Benjamin Barnett  None   N/A  New Zealand    3
# 3305913  2974792     Collin Romero  None   N/A          USA    3
# 3618833  3256272   Michelle Lawson  None   N/A     Malaysia    3
# 1443815  1298977       Aaron Rojas  None   N/A           UK   10
# 4984804  4486336      Jason Torres  None   N/A      Nigeria    4
# 881089    792727       Lisa Wright  None   N/A  New Zealand    8

# %%
rejected_filter.shape
# Out:
# (598780, 6)

# %%
accept_filter.shape
# Out:
# (4401220, 6)

# %% [markdown]
# #### Merging the modified dataset with accepted dataset

# %%
import pandas as pd
## Code snippet to merge data ~ .. 'outer' is like full join
dqValidity2 = pd.merge(rejected_filter,accept_filter,how='outer')

# %%
dqValidity2.shape
# Out:
# (5000000, 6)

# %%
dqValidity2.sample(10)
# Out:
#               id               name title  \
# 4228521  3805349       Lindsay Reed  None
# 2815696  2533575         Robin Webb  None
# 3020380  2717710        Tonya Keith  None
# 1139979  1025415   Alexandra Moreno  None
# 4026147  3623129       Nicole Joyce   N/A
# 272660    245308      Melissa Smith  None
# 4824861  4342340      Cheryl Brooks    MD
# 887187    798187  Katherine Johnson  None
# 2073510  1865439    Edwin Nicholson  None
# 3467245  3119826      Shannon Clark  None
#
#                                        email    country  age
# 4228521      lindsayreed_3805349@example.com    Germany   87
# 2815696        robinwebb_2533575@example.com   Malaysia   85
# 3020380       tonyakeith_2717710@example.com  Singapore   36
# 1139979  alexandramoreno_1025415@example.com      China   14
# 4026147      nicolejoyce_3623129@example.com    Germany   25
# 272660       melissasmith_245308@example.com    Germany   54
# 4824861     cherylbrooks_4342340@example.com    Nigeria   41
# 887187   katherinejohnson_798187@example.com   Malaysia   50
# 2073510   edwinnicholson_1865439@example.com  Australia   95
# 3467245     shannonclark_3119826@example.com  Australia   80

# %% [markdown]
# ## Completeness - Remove missing value in title column
# - Checking if any column consists of null value

# %%
dqValidity2.isnull().values.any()
# Out:
# True

# %%
null_counts = dqValidity2.isnull().sum()
print(null_counts)
# Out:
# id               0
# name             0
# title      4853727
# email            0
# country          0
# age              0
# dtype: int64

# %% [markdown]
# #### Dividing the Accepted dataset
# - not null value

# %%
# Filter rows where 'title' column is not null
not_null_rows = dqValidity2[dqValidity2['title'].notnull()]

# Print the filtered DataFrame
print("Rows where 'title' column is not null:")
not_null_rows.sample(10)
# Out:
# Rows where 'title' column is not null:
#               id               name title  \
# 4715494  4244042      Amanda Wilson    MD
# 111461    100346     Donna Atkinson   PhD
# 1405301  1264361  Christine Leblanc   N/A
# 1208979  1087678      Rhonda Sutton   N/A
# 688430    619308  Gregory Rodriguez   DVM
# 3169091  2851645    Gerald Williams   Jr.
# 4717461  4245802   Jessica Santiago   PhD
# 1517808  1365575      Kevin Johnson   PhD
# 4000834  3600354        Janice Case    MD
# 3605547  3244306       Joshua Ellis    MD
#
#                                         email      country  age
# 4715494      amandawilson_4244042@example.com       France   46
# 111461       donnaatkinson_100346@example.com     Malaysia   77
# 1405301  christineleblanc_1264361@example.com     Malaysia   19
# 1208979      rhondasutton_1087678@example.com      Nigeria   26
# 688430    gregoryrodriguez_619308@example.com  New Zealand   50
# 3169091    geraldwilliams_2851645@example.com       Canada   16
# 4717461   jessicasantiago_4245802@example.com           UK   90
# 1517808      kevinjohnson_1365575@example.com      Nigeria   51
# 4000834        janicecase_3600354@example.com       France   77
# 3605547       joshuaellis_3244306@example.com       Canada   83

# %%
not_null_rows.shape
# Out:
# (146273, 6)

# %% [markdown]
# #### Dividing the Rejected dataset
# - Null value

# %%
null_rows = dqValidity2[dqValidity2['title'].isnull()]

# %%
null_rows.shape
# Out:
# (4853727, 6)

# %%
null_rows.sample(10)
# Out:
#               id               name title  \
# 4171640  3754138        Colton Roth  None
# 924486    831665  Franklin Erickson  None
# 4366083  3929182        Karen Smith  None
# 365659    328874     Kimberly Green  None
# 1329089  1195819      John Robinson  None
# 2335459  2101089    Pamela Robinson  None
# 599087    538887   Makayla Robinson  None
# 3989983  3590574       Craig Arnold  None
# 2613824  2351859    Karen Hernandez  None
# 2726370  2453134       Robert Sloan  None
#
#                                        email      country  age
# 4171640       coltonroth_3754138@example.com    Singapore   76
# 924486   franklinerickson_831665@example.com     Malaysia   45
# 4366083       karensmith_3929182@example.com      Germany   32
# 365659      kimberlygreen_328874@example.com  New Zealand   72
# 1329089     johnrobinson_1195819@example.com    Australia   51
# 2335459   pamelarobinson_2101089@example.com    Australia   24
# 599087                                   N/A       Canada   11
# 3989983                                  N/A    Singapore   10
# 2613824   karenhernandez_2351859@example.com       France   58
# 2726370      robertsloan_2453134@example.com          USA   24

# %% [markdown]
# ### Modifying the Rejected dataset

# %%
null_rows.shape
# Out:
# (4853727, 6)

# %%
# Fill missing values in 'title' column with 'Not Applicable' and assign to a variable
# modify_null_rows = null_rows.copy()

# Replace null values in 'title' column with 'Not Applicable'
null_rows.loc[null_rows['title'].isnull(), 'title'] = 'N/A'

# %%
# after replace null to N/A
null_rows.shape
# Out:
# (4853727, 6)

# %%
# Print updated DataFrame
print("DataFrame with Nulls Replaced:")
null_rows.sample(5)
# Out:
# DataFrame with Nulls Replaced:
#               id            name title                              email  \
# 4322629  3890177     Jerry Cross   N/A     jerrycross_3890177@example.com
# 4256118  3830178     Scott House   N/A                                N/A
# 1862311  1675373      Cody Foley   N/A      codyfoley_1675373@example.com
# 2880186  2591611  Cindy Williams   N/A  cindywilliams_2591611@example.com
# 3876215  3488083   Stacey Torres   N/A   staceytorres_3488083@example.com
#
#            country  age
# 4322629    Nigeria   72
# 4256118      China    7
# 1862311  Australia   44
# 2880186         UK   64
# 3876215   Malaysia   47

# %% [markdown]
# #### Merge the modified rejected dataset with accepted dataset

# %%
import pandas as pd
## Code snippet to merge data ~ .. 'outer' is like full join
dqCompleteness = pd.merge(null_rows,not_null_rows,how='outer')

# %%
dqCompleteness.shape
# Out:
# (5000000, 6)

# %%
null_count = dqCompleteness.isnull().sum()
print(null_count)
# Out:
# id         0
# name       0
# title      0
# email      0
# country    0
# age        0
# dtype: int64

# %% [markdown]
# ### Optional to save as parquet file

# %%
# Save the DataFrame to a Parquet file
dqCompleteness.to_parquet('dqCompletenessBeforeUniqueness.parquet', index=False)
print("Data saved to dqCompletenessBeforeUniqueness.parquet file.")
# Out:
# Data saved to dqCompletenessBeforeUniqueness.parquet file.

# %% [markdown]
# # 5. Uniqueness Process
# - Check the duplicate value based on id and name column

# %%
dp_copy_1 = dqCompleteness.copy()

# %%
# Check any column with the string 
search_string = 'Michael Watson'
mask1 = dp_copy_1.apply(lambda x: x.astype(str).str.contains(search_string, case=False)).any(axis=1)
result1 = dp_copy_1[mask1]
result1.sample(10)
# Out:
#               id            name title                              email  \
# 3125418  2812303  Michael Watson   N/A  michaelwatson_2812303@example.com
# 809840    728528  Michael Watson   N/A   michaelwatson_728528@example.com
# 3658358  3291814  Michael Watson   N/A  michaelwatson_3291814@example.com
# 3617681  3255236  Michael Watson   DDS  michaelwatson_3255236@example.com
# 2045007  1839839  Michael Watson   N/A  michaelwatson_1839839@example.com
# 2564117  2307112  Michael Watson   N/A  michaelwatson_2307112@example.com
# 4590022  4130930  Michael Watson   N/A                                N/A
# 3509543  3157965  Michael Watson   N/A  michaelwatson_3157965@example.com
# 1025398   922351  Michael Watson   N/A   michaelwatson_922351@example.com
# 1198114  1077863  Michael Watson   N/A  michaelwatson_1077863@example.com
#
#              country  age
# 3125418  New Zealand   53
# 809840           USA   97
# 3658358      Nigeria   32
# 3617681    Australia   66
# 2045007          USA   93
# 2564117           UK   32
# 4590022       France    9
# 3509543  New Zealand   82
# 1025398    Singapore   56
# 1198114           UK   57

# %% [markdown]
# #### Dividing the Accepted and Rejected Dataset
# 1. Accepted  dataset - Not duplicate data
# 2. Rejected dataset - Duplicate data

# %% [markdown]
# - 'keep=False' means that all instances of a duplicated row are marked as duplicates.
# - This includes both the first occurrence of the duplicated row and all subsequent occurrences.
# - To easily identify and work with all duplicate entries in DataFrame.

# %%
# duplicate_mask = dp_copy.duplicated(subset=['id','name','title'], keep=False)
duplicate_mask = dp_copy_1.duplicated(subset=['id','name'], keep=False)

#Duplicate data
duplicate_ID_Name = dp_copy_1[duplicate_mask]

#non duplicate data
non_duplicate_ID_Name = dp_copy_1[~duplicate_mask]

# %%
#Duplicate value
print("\nDuplicate Data:")
duplicate_ID_Name.sample(10)
# Out:
# Duplicate Data:
#               id              name title                                email  \
# 375467    337715     Jesse Ramirez   N/A      jesseramirez_337715@example.com
# 2627207  2363897     Cheryl Benson   N/A     cherylbenson_2363897@example.com
# 4574136  4116658      Roger Rivera   N/A      rogerrivera_4116658@example.com
# 933515    839767    Alexander Soto   N/A     alexandersoto_839767@example.com
# 4661532  4195322    Steven Johnson   N/A    stevenjohnson_4195322@example.com
# 4514423  4062775      Richard Kent   N/A      richardkent_4062775@example.com
# 3134816  2820813      Joseph Doyle   N/A      josephdoyle_2820813@example.com
# 331988    298614      Heather Reed   N/A       heatherreed_298614@example.com
# 4400518  3960200  Virginia Herrera   N/A                                  N/A
# 4073662  3666005  Gregory Thompson   N/A  gregorythompson_3666005@example.com
#
#              country  age
# 375467     Singapore   96
# 2627207    Singapore   73
# 4574136  New Zealand   49
# 933515         China   64
# 4661532        India   60
# 4514423     Malaysia   93
# 3134816    Australia   74
# 331988     Singapore   96
# 4400518          USA    7
# 4073662  New Zealand   39

# %%
print("\nNot Duplicate Data:")
non_duplicate_ID_Name.sample(10)
# Out:
# Not Duplicate Data:
#               id               name title  \
# 4212124  3790582       Natasha Chen   N/A
# 31268      28198        Roger Henry   N/A
# 875106    787341         James Pena   N/A
# 2730293  2456692        Randy Moore   N/A
# 1071498   963802       Ruth Jenkins   N/A
# 3159570  2843080       Anna Sellers   N/A
# 2480827  2232059  Allison Dougherty   N/A
# 3835517  3451413   Deborah Gonzalez   N/A
# 677845    609785    Joseph Franklin   N/A
# 3207431  2886065     Karen Trujillo   N/A
#
#                                         email      country  age
# 4212124                                   N/A      Nigeria    6
# 31268            rogerhenry_28198@example.com       Canada   18
# 875106                                    N/A       France    5
# 2730293        randymoore_2456692@example.com     Malaysia   13
# 1071498        ruthjenkins_963802@example.com      Germany   86
# 3159570       annasellers_2843080@example.com        China   73
# 2480827  allisondougherty_2232059@example.com  New Zealand   77
# 3835517   deborahgonzalez_3451413@example.com      Germany   48
# 677845      josephfranklin_609785@example.com     Malaysia   52
# 3207431     karentrujillo_2886065@example.com        China   56

# %% [markdown]
# #### Modify the rejected dataset - Uniqueness Process
# 1. Remove the duplicate value based on id and name

# %%
deduplicate_ID_Name_df = duplicate_ID_Name.drop_duplicates(subset=['id','name'])

# Display the deduplicated DataFrame
print("\nDeduplicated DataFrame based on ID and Name:")
deduplicate_ID_Name_df.sample(10)
# Out:
# Deduplicated DataFrame based on ID and Name:
#               id                name title  \
# 190471    171416          Eric James   N/A
# 4848062  4363176       Kelsey Watson   N/A
# 915021    823155       Kimberly Reed   N/A
# 3612909  3250929     Debra Wilkinson   N/A
# 1261741  1135223    Austin Wilkinson   N/A
# 4464302  4017623        Robert Lewis   N/A
# 1086493   977337  Christina Santiago   N/A
# 3108019  2796631           Julian Yu   N/A
# 4590539  4131397    Michelle Kennedy   N/A
# 1755828  1579769     Jenna Rodriguez   N/A
#
#                                         email      country  age
# 190471           ericjames_171416@example.com        India   44
# 4848062      kelseywatson_4363176@example.com  New Zealand   27
# 915021                                    N/A       France    3
# 3612909    debrawilkinson_3250929@example.com    Singapore   69
# 1261741   austinwilkinson_1135223@example.com           UK   16
# 4464302                                   N/A     Malaysia    2
# 1086493  christinasantiago_977337@example.com    Australia   35
# 3108019          julianyu_2796631@example.com  New Zealand   96
# 4590539   michellekennedy_4131397@example.com      Nigeria   81
# 1755828    jennarodriguez_1579769@example.com          USA   81

# %% [markdown]
# #### Merge rejected dataset and accepted dataset

# %%
import pandas as pd
## Code snippet to merge data ~ .. 'outer' is like full join
dqUniquenessIDName = pd.merge(deduplicate_ID_Name_df,non_duplicate_ID_Name,how='outer')

# %%
dqUniquenessIDName.shape
# Out:
# (4500000, 6)

# %%
dqUniquenessIDName.sample(5)
# Out:
#               id            name title                              email  \
# 1391762  1391763  Lindsay Miller   N/A  lindsaymiller_1391763@example.com
# 455388    455389   Rebecca Lopez   N/A    rebeccalopez_455389@example.com
# 1423927  1423928   Nicole Howard   N/A   nicolehoward_1423928@example.com
# 3572282  3572283   Julie Pearson   N/A   juliepearson_3572283@example.com
# 3547997  3547998   Brian Mccarty   N/A   brianmccarty_3547998@example.com
#
#            country  age
# 1391762         UK   25
# 455388   Singapore   44
# 1423927  Singapore   58
# 3572282   Malaysia   73
# 3547997   Malaysia   53

# %% [markdown]
# ### Optional to save as parquet

# %%
# Save the DataFrame to a Parquet file
dqUniquenessIDName.to_parquet('dqdatademo_processed.parquet', index=False)
print("Data saved to dqdatademo_processed.parquet file.")
# Out:
# Data saved to dqdatademo_processed.parquet file.

# %% [markdown]
# #### Ensure there are no duplicate value

# %%
# Check any column with the string 
search_string = 'Michael Watson'
mask = dqUniquenessIDName.apply(lambda x: x.astype(str).str.contains(search_string, case=False)).any(axis=1)
result = dqUniquenessIDName[mask]
print(result)
# Out:
#               id            name title                              email  \
# 10848      10849  Michael Watson   N/A    michaelwatson_10849@example.com
# 27644      27645  Michael Watson   N/A    michaelwatson_27645@example.com
# 44742      44743  Michael Watson   N/A    michaelwatson_44743@example.com
# 120251    120252  Michael Watson   N/A   michaelwatson_120252@example.com
# 122351    122352  Michael Watson   N/A   michaelwatson_122352@example.com
# ...          ...             ...   ...                                ...
# 4383145  4383146  Michael Watson   N/A  michaelwatson_4383146@example.com
# 4444522  4444523  Michael Watson   N/A                                N/A
# 4454429  4454430  Michael Watson   N/A  michaelwatson_4454430@example.com
# 4467075  4467076  Michael Watson   N/A  michaelwatson_4467076@example.com
# 4473830  4473831  Michael Watson   N/A  michaelwatson_4473831@example.com
#
#              country  age
# 10848          India   85
# 27644    New Zealand   39
# 44742    New Zealand   53
# 120251       Nigeria   91
# 122351   New Zealand   26
# ...              ...  ...
# 4383145       Canada   63
# 4444522    Australia    8
# 4454429        China   46
# 4467075    Singapore   35
# 4473830    Australia   36
#
# [204 rows x 6 columns]

# %%
# Step 2: Check for duplicates within the identified rows
duplicates = result[result.duplicated()]

# print("Rows containing the search string 'Cody Ross':")
# print(result)
print("\nDuplicate rows containing the search string 'Michael Watson':")
print(duplicates)
# Out:
# Duplicate rows containing the search string 'Michael Watson':
# Empty DataFrame
# Columns: [id, name, title, email, country, age]
# Index: []

# %% [markdown]
# # To upload into Azure Blob

# %%
# Convert DataFrame to Parquet format
parquet_file_path = "dqdatademo_processed.parquet"
table = pa.Table.from_pandas(dqUniquenessIDName)
pq.write_table(table, parquet_file_path)

# %%
print(parquet_file_path)
# Out:
# dqdatademo_processed.parquet

# %%
import pandas as pd

# Read the Parquet file into a DataFrame
df_from_parquet = pd.read_parquet(parquet_file_path)

# %%
df_from_parquet.sample(5)
# Out:
#               id                 name title  \
# 1879754  1879755        Michael Smith   N/A
# 1370231  1370232       Michael Martin   N/A
# 1733529  1733530          Nancy Burke   N/A
# 547399    547400  Katherine Gallagher   N/A
# 644135    644136          Scott Smith   N/A
#
#                                          email  country  age
# 1879754       michaelsmith_1879755@example.com       UK   41
# 1370231      michaelmartin_1370232@example.com  Nigeria   63
# 1733529                                    N/A  Nigeria   11
# 547399   katherinegallagher_547400@example.com      USA   95
# 644135           scottsmith_644136@example.com    India   82

# %%
# Upload the Parquet file back to Azure Blob Storage
parquet_blob_client = container_client.get_blob_client("03-Silver/dqdatademo_processed.parquet")
with open(parquet_file_path, "rb") as data:
    parquet_blob_client.upload_blob(data)
